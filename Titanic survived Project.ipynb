# %% [markdown]
# # Titanic survived Project

# %%
import pandas as pd
import numpy as np

# %%
titanic_train = pd.read_csv(r'titanic_train.csv')

# %%
titanic_train.head()
# Out:
#    Unnamed: 0  PassengerId  Survived  Pclass  \
# 0           0            1         0       3
# 1           1            2         1       1
# 2           2            3         1       3
# 3           3            4         1       1
# 4           4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_train.drop(['Unnamed: 0'], axis=1, inplace=True)

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# # HOW TO CHECK UNIQUE VALUES OF ANY COLUMN

# %%
titanic_train["Survived"].unique()                 #Similarly you can check any column unique values
# Out:
# array([0, 1], dtype=int64)

# %% [markdown]
# # How to replace categories using pandas method

# %%
titanic_train["Survived"].replace({0:'Died',1:'Survived'},inplace=True)

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1      Died       3
# 1            2  Survived       1
# 2            3  Survived       3
# 3            4  Survived       1
# 4            5      Died       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
#Similarly you can replace any category in the dataset. Try yourself replacing 'Pclass'

titanic_train["Pclass"].replace({1:'1st Class',2:'2nd Class',3:'3rd Class'},inplace=True)

# %%
titanic_train.head()
# Out:
#    PassengerId  Survived     Pclass  \
# 0            1      Died  3rd Class
# 1            2  Survived  1st Class
# 2            3  Survived  3rd Class
# 3            4  Survived  1st Class
# 4            5      Died  3rd Class
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
titanic_train.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# # Find all the passangers who's age is missing

# %%
age_missing = titanic_train[titanic_train['Age'].isna()]

#Or
#age_missing = titanic_train[titanic_train.Age.isin(['NaN'])]

age_missing
# Out:
#      PassengerId  Survived     Pclass  \
# 5              6      Died  3rd Class
# 17            18  Survived  2nd Class
# 19            20  Survived  3rd Class
# 26            27      Died  3rd Class
# 28            29  Survived  3rd Class
# ..           ...       ...        ...
# 859          860      Died  3rd Class
# 863          864      Died  3rd Class
# 868          869      Died  3rd Class
# 878          879      Died  3rd Class
# 888          889      Died  3rd Class
#
#                                          Name     Sex  Age  SibSp  Parch  \
# 5                            Moran, Mr. James    male  NaN      0      0
# 17               Williams, Mr. Charles Eugene    male  NaN      0      0
# 19                    Masselmani, Mrs. Fatima  female  NaN      0      0
# 26                    Emir, Mr. Farred Chehab    male  NaN      0      0
# 28              O'Dwyer, Miss. Ellen "Nellie"  female  NaN      0      0
# ..                                        ...     ...  ...    ...    ...
# 859                          Razi, Mr. Raihed    male  NaN      0      0
# 863         Sage, Miss. Dorothy Edith "Dolly"  female  NaN      8      2
# 868               van Melkebeke, Mr. Philemon    male  NaN      0      0
# 878                        Laleff, Mr. Kristo    male  NaN      0      0
# 888  Johnston, Miss. Catherine Helen "Carrie"  female  NaN      1      2
#
#          Ticket     Fare Cabin Embarked
# 5        330877   8.4583   NaN        Q
# 17       244373  13.0000   NaN        S
# 19         2649   7.2250   NaN        C
# 26         2631   7.2250   NaN        C
# 28       330959   7.8792   NaN        Q
# ..          ...      ...   ...      ...
# 859        2629   7.2292   NaN        C
# 863    CA. 2343  69.5500   NaN        S
# 868      345777   9.5000   NaN        S
# 878      349217   7.8958   NaN        S
# 888  W./C. 6607  23.4500   NaN        S
#
# [177 rows x 12 columns]

# %% [markdown]
# # Find only those passangers who's age is present in the dataset (Equal to NOT IN)

# %%
with_age = titanic_train[titanic_train['Age'].notnull()]

# or
# with_age = titanic_train[~titanic_train.Age.isin(['NaN'])]

with_age
# Out:
#      PassengerId  Survived     Pclass  \
# 0              1      Died  3rd Class
# 1              2  Survived  1st Class
# 2              3  Survived  3rd Class
# 3              4  Survived  1st Class
# 4              5      Died  3rd Class
# ..           ...       ...        ...
# 885          886      Died  3rd Class
# 886          887      Died  2nd Class
# 887          888  Survived  1st Class
# 889          890  Survived  1st Class
# 890          891      Died  3rd Class
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 885               Rice, Mrs. William (Margaret Norton)  female  39.0      0
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 885      5            382652  29.1250   NaN        Q
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [714 rows x 12 columns]

# %%
# Find the Maximum fare

max(titanic_train['Fare'])
# Out:
# 512.3292

# %%
max_ = titanic_train[titanic_train.Fare == max(titanic_train["Fare"])]

max_
# Out:
#      PassengerId  Survived     Pclass                                Name  \
# 258          259  Survived  1st Class                    Ward, Miss. Anna
# 679          680  Survived  1st Class  Cardeza, Mr. Thomas Drake Martinez
# 737          738  Survived  1st Class              Lesurer, Mr. Gustave J
#
#         Sex   Age  SibSp  Parch    Ticket      Fare        Cabin Embarked
# 258  female  35.0      0      0  PC 17755  512.3292          NaN        C
# 679    male  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 737    male  35.0      0      0  PC 17755  512.3292         B101        C

# %%
#Another way formula   isin mean ==

# max_fare = titanic_train[titanic_train.Fare.isin([max(titanic_train['Fare'])])]

# %% [markdown]
# # Multiple conditions

# %%
class1_female = titanic_train[titanic_train.Pclass.isin(['1st Class']) & titanic_train.Sex.isin(['female'])]

class1_female
# Out:
#      PassengerId  Survived     Pclass  \
# 1              2  Survived  1st Class
# 3              4  Survived  1st Class
# 11            12  Survived  1st Class
# 31            32  Survived  1st Class
# 52            53  Survived  1st Class
# ..           ...       ...        ...
# 856          857  Survived  1st Class
# 862          863  Survived  1st Class
# 871          872  Survived  1st Class
# 879          880  Survived  1st Class
# 887          888  Survived  1st Class
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# 856         Wick, Mrs. George Dennick (Mary Hitchcock)  female  45.0      1
# 862  Swift, Mrs. Frederick Joel (Margaret Welles Ba...  female  48.0      0
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch    Ticket      Fare Cabin Embarked
# 1        0  PC 17599   71.2833   C85        C
# 3        0    113803   53.1000  C123        S
# 11       0    113783   26.5500  C103        S
# 31       0  PC 17569  146.5208   B78        C
# 52       0  PC 17572   76.7292   D33        C
# ..     ...       ...       ...   ...      ...
# 856      1     36928  164.8667   NaN        S
# 862      0     17466   25.9292   D17        S
# 871      1     11751   52.5542   D35        S
# 879      1     11767   83.1583   C50        C
# 887      0    112053   30.0000   B42        S
#
# [94 rows x 12 columns]

# %%
class1_male = titanic_train[titanic_train.Pclass.isin(['2nd Class']) & titanic_train.Sex.isin(['male'])]

class1_male
# Out:
#      PassengerId  Survived     Pclass                           Name   Sex  \
# 17            18  Survived  2nd Class   Williams, Mr. Charles Eugene  male
# 20            21      Died  2nd Class           Fynney, Mr. Joseph J  male
# 21            22  Survived  2nd Class          Beesley, Mr. Lawrence  male
# 33            34      Died  2nd Class          Wheadon, Mr. Edward H  male
# 70            71      Died  2nd Class     Jenkin, Mr. Stephen Curnow  male
# ..           ...       ...        ...                            ...   ...
# 848          849      Died  2nd Class              Harper, Rev. John  male
# 861          862      Died  2nd Class    Giles, Mr. Frederick Edward  male
# 864          865      Died  2nd Class         Gill, Mr. John William  male
# 883          884      Died  2nd Class  Banfield, Mr. Frederick James  male
# 886          887      Died  2nd Class          Montvila, Rev. Juozas  male
#
#       Age  SibSp  Parch            Ticket  Fare Cabin Embarked
# 17    NaN      0      0            244373  13.0   NaN        S
# 20   35.0      0      0            239865  26.0   NaN        S
# 21   34.0      0      0            248698  13.0   D56        S
# 33   66.0      0      0        C.A. 24579  10.5   NaN        S
# 70   32.0      0      0        C.A. 33111  10.5   NaN        S
# ..    ...    ...    ...               ...   ...   ...      ...
# 848  28.0      0      1            248727  33.0   NaN        S
# 861  21.0      1      0             28134  11.5   NaN        S
# 864  24.0      0      0            233866  13.0   NaN        S
# 883  28.0      0      0  C.A./SOTON 34068  10.5   NaN        S
# 886  27.0      0      0            211536  13.0   NaN        S
#
# [108 rows x 12 columns]

# %%
Survived_female = titanic_train[titanic_train.Survived.isin(['Survived']) & titanic_train.Sex.isin(['female'])]

Survived_female
# Out:
#      PassengerId  Survived     Pclass  \
# 1              2  Survived  1st Class
# 2              3  Survived  3rd Class
# 3              4  Survived  1st Class
# 8              9  Survived  3rd Class
# 9             10  Survived  2nd Class
# ..           ...       ...        ...
# 874          875  Survived  2nd Class
# 875          876  Survived  3rd Class
# 879          880  Survived  1st Class
# 880          881  Survived  2nd Class
# 887          888  Survived  1st Class
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)  female  27.0      0
# 9                  Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# ..                                                 ...     ...   ...    ...
# 874              Abelson, Mrs. Samuel (Hannah Wizosky)  female  28.0      1
# 875                   Najib, Miss. Adele Kiamie "Jane"  female  15.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 880       Shelley, Mrs. William (Imanita Parrish Hall)  female  25.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 8        2            347742  11.1333   NaN        S
# 9        0            237736  30.0708   NaN        C
# ..     ...               ...      ...   ...      ...
# 874      0         P/PP 3381  24.0000   NaN        C
# 875      0              2667   7.2250   NaN        C
# 879      1             11767  83.1583   C50        C
# 880      1            230433  26.0000   NaN        S
# 887      0            112053  30.0000   B42        S
#
# [233 rows x 12 columns]
